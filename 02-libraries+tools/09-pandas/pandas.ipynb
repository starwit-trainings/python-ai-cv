# %% [markdown]
# # Examples and Tasks with Pandas
#
# Pandas is another Python library that provides great functions to work with data. Though being very handy it is not exactly fast. So be aware when working with large datasets - this is going to be slow with Pandas. However for data exploration and testing of functions Pandas is super helpful.
#
# ## Loading data from files
#
# The following three examples show, how to load response time data from three different file types.

# %%
import pandas as pd

data = pd.read_csv("data-samples/responsetimes.csv")
data

# %%
import pandas as pd

data = pd.read_excel("data-samples/responsetimes.xlsx")
data

# %%
import pandas as pd

data = pd.read_excel("data-samples/responsetimes.ods", engine="odf")
data

# %% [markdown]
# ## Connecting to data bases
#
# As we put data into Timescale, let's connect and see if Pandas can work with query results too.

# %%
import psycopg2
import logging
from psycopg2.extras import LoggingConnection

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

db_settings = {
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "database": "sampledata",
}

conn = psycopg2.connect(connection_factory=LoggingConnection, **db_settings)
conn.initialize(logger)
cursor = conn.cursor()
# use the cursor to interact with your database
cursor.execute("SELECT * FROM public.responsetimes")
print(cursor.fetchone())

df = pd.read_sql_query('SELECT * FROM public.responsetimes',con=conn)
df
# Out:
# DEBUG:__main__:b'SELECT * FROM public.responsetimes'
# /tmp/ipykernel_305077/2219597650.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('SELECT * FROM public.responsetimes',con=conn)
# DEBUG:__main__:b'SELECT * FROM public.responsetimes'
# ('http://worldtimeapi.org/api/timezone/Europe/Berlin', datetime.datetime(2024, 6, 6, 12, 34, 56, tzinfo=datetime.timezone.utc), 54782)
#                                                   url  \
# 0   http://worldtimeapi.org/api/timezone/Europe/Be...
# 1   http://worldtimeapi.org/api/timezone/Europe/Be...
# 2   http://worldtimeapi.org/api/timezone/Europe/Be...
# 3   http://worldtimeapi.org/api/timezone/Europe/Be...
# 4   http://worldtimeapi.org/api/timezone/Europe/Be...
# 5   http://worldtimeapi.org/api/timezone/Europe/Be...
# 6   http://worldtimeapi.org/api/timezone/Europe/Be...
# 7   http://worldtimeapi.org/api/timezone/Europe/Be...
# 8   http://worldtimeapi.org/api/timezone/Europe/Be...
# 9   http://worldtimeapi.org/api/timezone/Europe/Be...
# 10  http://worldtimeapi.org/api/timezone/Europe/Be...
# 11  http://worldtimeapi.org/api/timezone/Europe/Be...
# 12  http://worldtimeapi.org/api/timezone/Europe/Be...
# 13  http://worldtimeapi.org/api/timezone/Europe/Be...
# 14  http://worldtimeapi.org/api/timezone/Europe/Be...
# 15  http://worldtimeapi.org/api/timezone/Europe/Be...
# 16  http://worldtimeapi.org/api/timezone/Europe/Be...
# 17  http://worldtimeapi.org/api/timezone/Europe/Be...
# 18  http://worldtimeapi.org/api/timezone/Europe/Be...
# 19  http://worldtimeapi.org/api/timezone/Europe/Be...
# 20  http://worldtimeapi.org/api/timezone/Europe/Be...
# 21  http://worldtimeapi.org/api/timezone/Europe/Be...
#
#                         measuretime  responsetime
# 0         2024-06-06 12:34:56+00:00         54782
# 1  2024-06-08 22:13:50.324863+00:00             0
# 2  2024-06-08 22:15:46.104013+00:00             0
# 3  2024-06-08 22:15:46.147828+00:00             0
# 4  2024-06-08 22:15:46.190904+00:00             0
# 5  2024-06-08 22:15:46.230391+00:00             0
# 6  2024-06-08 22:15:46.271936+00:00             0
# 7  2024-06-08 22:15:46.336191+00:00             0
# 8  2024-06-08 22:15:46.380353+00:00             0
# 9  2024-06-08 22:15:46.432550+00:00             0
# 10 2024-06-08 22:15:46.481738+00:00             0
# 11 2024-06-08 22:15:46.524668+00:00             0
# 12 2024-06-08 22:16:57.699006+00:00         37198
# 13 2024-06-08 22:16:57.738982+00:00         38530
# 14 2024-06-08 22:16:57.777477+00:00         36999
# 15 2024-06-08 22:16:57.823518+00:00         44617
# 16 2024-06-08 22:16:57.865038+00:00         39262
# 17 2024-06-08 22:16:57.909270+00:00         42367
# 18 2024-06-08 22:16:57.948710+00:00         37709
# 19 2024-06-08 22:16:57.988866+00:00         39012
# 20 2024-06-08 22:16:58.031782+00:00         41786
# 21 2024-06-08 22:16:58.070866+00:00         37916

# %% [markdown]
# Now let's add data to the same database. First let's define again our response time function and use it, to generate some data.

# %%
from datetime import datetime
import requests
url = "http://google.com"

def measureResponseTimes(url, attempts):
    timeticks = []
    values = []
    result = {}

    for i in range(attempts):
        response = requests.post(url)
        timeticks.append(datetime.now())
        values.append(response.elapsed.total_seconds()) 
    result["timeticks"] = timeticks
    result["values"] = values
    return result

result = measureResponseTimes(url, 10)

# %%
# Convert data to a pandas DataFrame
df = pd.DataFrame(result)

# Add a column for URL (assuming the URL is the same for all records)
df['url'] = url  # Replace with the actual URL or remove if not applicable

# Rename columns to match the table structure
df.rename(columns={'timeticks': 'measuretime', 'values': 'responsetime'}, inplace=True)

# Convert responsetime to BIGINT (nanoseconds)
df['responsetime'] = (df['responsetime'] * 1e9).astype(int)

# Insert data into the PostgreSQL table
df.to_sql('responsetimes', conn, if_exists='fail', index=False)
# Out:
# /tmp/ipykernel_305077/28548997.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql('responsetimes', conn, if_exists='fail', index=False)
# DEBUG:__main__:b"\n        SELECT\n            name\n        FROM\n            sqlite_master\n        WHERE\n            type IN ('table', 'view')\n            AND name=?;\n        "
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/psycopg2/extras.py:445, in LoggingCursor.execute(self, query, vars)
#     444 try:
# --> 445     return super().execute(query, vars)
#     446 finally:
#
# SyntaxError: syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[20], line 15
#      12 df
#      14 # Insert data into the PostgreSQL table
# ---> 15 df.to_sql('responsetimes', conn, if_exists='fail', index=False)
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/core/generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2850, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2839             raise ValueError(f"{col} ({my_type}) not a string")
#    2841 table = SQLiteTable(
#    2842     name,
#    2843     self,
#    (...)
#    2848     dtype=dtype,
#    2849 )
# -> 2850 table.create()
#    2851 return table.insert(chunksize, method)
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:984, in SQLTable.create(self)
#     983 def create(self) -> None:
# --> 984     if self.exists():
#     985         if self.if_exists == "fail":
#     986             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:970, in SQLTable.exists(self)
#     969 def exists(self):
# --> 970     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2865, in SQLiteDatabase.has_table(self, name, schema)
#    2854 wld = "?"
#    2855 query = f"""
#    2856 SELECT
#    2857     name
#    (...)
#    2862     AND name={wld};
#    2863 """
# -> 2865 return len(self.execute(query, [name]).fetchall()) > 0
#
# File ~/workspaces/tutorials/trainings/python/02-libraries+tools/.venv/lib/python3.11/site-packages/pandas/io/sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql '
#         SELECT
#             name
#         FROM
#             sqlite_master
#         WHERE
#             type IN ('table', 'view')
#             AND name=?;
#         ': syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
