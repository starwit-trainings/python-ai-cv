# %% [markdown]
# # Examples and Tasks with Pandas
#
# Pandas is another Python library that provides great functions to work with data. Though being very handy it is not exactly fast. So be aware when working with large datasets - this is going to be slow with Pandas. However for data exploration and testing of functions Pandas is super helpful.
#
# ## Loading data from files
#
# The following three examples show, how to load response time data from three different file types.

# %%
import pandas as pd

data = pd.read_csv("data-samples/responsetimes.csv")
data

# %%
import pandas as pd

data = pd.read_excel("data-samples/responsetimes.xlsx")
data

# %%
import pandas as pd

data = pd.read_excel("data-samples/responsetimes.ods", engine="odf")
data

# %% [markdown]
# ## Connecting to data bases
#
# As we put data into Timescale, let's connect and see if Pandas can work with query results too.

# %%
import psycopg2
import logging
from psycopg2.extras import LoggingConnection

logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

db_settings = {
    "user": "postgres",
    "password": "password",
    "host": "localhost",
    "database": "sampledata",
}

conn = psycopg2.connect(connection_factory=LoggingConnection, **db_settings)
conn.initialize(logger)
cursor = conn.cursor()
# use the cursor to interact with your database
cursor.execute("SELECT * FROM public.responsetimes")
print(cursor.fetchone())

df = pd.read_sql_query('SELECT * FROM public.responsetimes',con=conn)
df
# Out:
# DEBUG:__main__:b'SELECT * FROM public.responsetimes'
# /tmp/ipykernel_394259/2219597650.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('SELECT * FROM public.responsetimes',con=conn)
# DEBUG:__main__:b'SELECT * FROM public.responsetimes'
# ('http://worldtimeapi.org/api/timezone/Europe/Berlin', datetime.datetime(2024, 6, 6, 12, 34, 56, tzinfo=datetime.timezone.utc), 54782)
#                                                   url  \
# 0   http://worldtimeapi.org/api/timezone/Europe/Be...
# 1   http://worldtimeapi.org/api/timezone/Europe/Be...
# 2   http://worldtimeapi.org/api/timezone/Europe/Be...
# 3   http://worldtimeapi.org/api/timezone/Europe/Be...
# 4   http://worldtimeapi.org/api/timezone/Europe/Be...
# 5   http://worldtimeapi.org/api/timezone/Europe/Be...
# 6   http://worldtimeapi.org/api/timezone/Europe/Be...
# 7   http://worldtimeapi.org/api/timezone/Europe/Be...
# 8   http://worldtimeapi.org/api/timezone/Europe/Be...
# 9   http://worldtimeapi.org/api/timezone/Europe/Be...
# 10  http://worldtimeapi.org/api/timezone/Europe/Be...
# 11                                  http://google.com
# 12                                  http://google.com
# 13                                  http://google.com
# 14                                  http://google.com
# 15                                  http://google.com
# 16                                  http://google.com
# 17                                  http://google.com
# 18                                  http://google.com
# 19                                  http://google.com
# 20                                  http://google.com
# 21                                    http://heise.de
# 22                                    http://heise.de
# 23                                    http://heise.de
# 24                                    http://heise.de
# 25                                    http://heise.de
# 26                                    http://heise.de
# 27                                    http://heise.de
# 28                                    http://heise.de
# 29                                    http://heise.de
# 30                                    http://heise.de
# 31  http://worldtimeapi.org/api/timezone/Europe/Be...
# 32  http://worldtimeapi.org/api/timezone/Europe/Be...
# 33  http://worldtimeapi.org/api/timezone/Europe/Be...
# 34  http://worldtimeapi.org/api/timezone/Europe/Be...
# 35  http://worldtimeapi.org/api/timezone/Europe/Be...
# 36  http://worldtimeapi.org/api/timezone/Europe/Be...
# 37  http://worldtimeapi.org/api/timezone/Europe/Be...
# 38  http://worldtimeapi.org/api/timezone/Europe/Be...
# 39  http://worldtimeapi.org/api/timezone/Europe/Be...
# 40  http://worldtimeapi.org/api/timezone/Europe/Be...
# 41  http://worldtimeapi.org/api/timezone/Europe/Be...
#
#                         measuretime  responsetime
# 0         2024-06-06 12:34:56+00:00         54782
# 1  2024-06-08 22:16:57.699006+00:00         37198
# 2  2024-06-08 22:16:57.738982+00:00         38530
# 3  2024-06-08 22:16:57.777477+00:00         36999
# 4  2024-06-08 22:16:57.823518+00:00         44617
# 5  2024-06-08 22:16:57.865038+00:00         39262
# 6  2024-06-08 22:16:57.909270+00:00         42367
# 7  2024-06-08 22:16:57.948710+00:00         37709
# 8  2024-06-08 22:16:57.988866+00:00         39012
# 9  2024-06-08 22:16:58.031782+00:00         41786
# 10 2024-06-08 22:16:58.070866+00:00         37916
# 11 2024-06-09 20:39:06.324269+00:00        259922
# 12 2024-06-09 20:39:06.507117+00:00        182074
# 13 2024-06-09 20:39:06.671443+00:00        161160
# 14 2024-06-09 20:39:06.831507+00:00        159192
# 15 2024-06-09 20:39:07.041693+00:00        209389
# 16 2024-06-09 20:39:07.213905+00:00        170698
# 17 2024-06-09 20:39:07.373305+00:00        158315
# 18 2024-06-09 20:39:07.531004+00:00        156815
# 19 2024-06-09 20:39:07.752364+00:00        220443
# 20 2024-06-09 20:39:07.907719+00:00        154337
# 21 2024-06-09 20:39:36.865822+00:00         98161
# 22 2024-06-09 20:39:37.136586+00:00         83463
# 23 2024-06-09 20:39:37.369774+00:00         73126
# 24 2024-06-09 20:39:37.594979+00:00         84649
# 25 2024-06-09 20:39:37.824052+00:00         69268
# 26 2024-06-09 20:39:38.052221+00:00         73698
# 27 2024-06-09 20:39:38.254114+00:00         67183
# 28 2024-06-09 20:39:38.546156+00:00        111230
# 29 2024-06-09 20:39:38.752129+00:00         66002
# 30 2024-06-09 20:39:38.958857+00:00         80992
# 31 2024-06-09 20:44:52.048268+00:00        100233
# 32 2024-06-09 20:55:30.021129+00:00         83201
# 33 2024-06-09 20:55:30.088830+00:00         49642
# 34 2024-06-09 20:55:30.168195+00:00         57330
# 35 2024-06-09 20:55:30.244462+00:00         56420
# 36 2024-06-09 20:55:30.316427+00:00         50874
# 37 2024-06-09 20:55:30.386293+00:00         52250
# 38 2024-06-09 20:55:30.462359+00:00         51869
# 39 2024-06-09 20:55:30.536076+00:00         57064
# 40 2024-06-09 20:55:30.622771+00:00         63302
# 41 2024-06-09 20:55:30.707839+00:00         62652

# %% [markdown]
# Now let's add data to the same database. First let's define again our response time function and use it, to generate some data.

# %%
from datetime import datetime
import requests
url = "http://heise.de"

def measureResponseTimes(url, attempts):
    timeticks = []
    values = []
    result = {}

    for i in range(attempts):
        response = requests.post(url)
        timeticks.append(datetime.now())
        values.append(response.elapsed.total_seconds()) 
    result["timeticks"] = timeticks
    result["values"] = values
    return result

result = measureResponseTimes(url, 10)

# %% [markdown]
# Now add data to database. TODO debug generated SQL script.

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:password@localhost:5432/sampledata")

import pandas as pd

# Convert data to a pandas DataFrame
df = pd.DataFrame(result)

# Add a column for URL (assuming the URL is the same for all records)
df['url'] = url  # Replace with the actual URL or remove if not applicable

# Rename columns to match the table structure
df.rename(columns={'timeticks': 'measuretime', 'values': 'responsetime'}, inplace=True)

# Convert responsetime to BIGINT (nanoseconds)
df['responsetime'] = (df['responsetime'] * 1000000).astype(int)

# Insert data into the PostgreSQL table
df.to_sql('responsetimes', engine, if_exists='append', index=False)
# Out:
# 10
